# %%
import pandas as pd
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
#Uploading strong scaling data
d1 = pd.read_csv('data.csv')
d1.head(10)
# Out:
#    nproc       npts   time_v1       error_v1   time_v2       error_v2  \
# 0      1  16777216,  0.055478  2.858345e-10,  0.055927  2.858345e-10,
# 1      2  16777216,  0.028847  2.858345e-10,  0.028975  2.858345e-10,
# 2      4  16777216,  0.015357  2.858345e-10,  0.014989  2.858345e-10,
# 3      8  16777216,  0.007934  2.858345e-10,  0.008011  2.858345e-10,
# 4     16  16777216,  0.004396  2.858345e-10,  0.004405  2.858345e-10,
# 5     32  16777216,  0.002816  2.858345e-10,  0.002809  2.858345e-10,
# 6     64  16777216,  0.001409  2.858345e-10,  0.001395  2.858345e-10,
#
#     time_v3       error_v3   time_v4      error_v4
# 0  0.055488  2.858345e-10,  0.055578  2.860000e-10
# 1  0.028840  2.858345e-10,  0.028855  2.860000e-10
# 2  0.014879  2.858345e-10,  0.014904  2.860000e-10
# 3  0.007978  2.858345e-10,  0.007957  2.860000e-10
# 4  0.004370  2.858345e-10,  0.004328  2.860000e-10
# 5  0.002753  2.858345e-10,  0.002736  2.860000e-10
# ...

# %%
figure(8)
loglog(d1.nproc,d1.time_v1,'*-',label = 'v1')
loglog(d1.nproc,d1.time_v2,'--',label = 'v2')
loglog(d1.nproc,d1.time_v3,'*-',label = 'v3')
loglog(d1.nproc,d1.time_v4,'--',label = 'v4')
title('Comparing versions')
xlabel('number of processors')
ylabel('time')
legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
